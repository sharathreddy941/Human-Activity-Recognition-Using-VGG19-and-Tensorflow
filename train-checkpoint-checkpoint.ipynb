# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D

# %%
train_path = 'C:/Users/Vishwa/Desktop/HAR final/datasets'
test_path = 'C:/Users/Vishwa/Desktop/HAR final/datasets'

# %%
activities = os.listdir(train_path)
num_classes = len(activities)
print(num_classes)
# Out:
# 3

# %%
train_frames = []
train_labels = []
for i, activity in enumerate(activities):
    activity_path = os.path.join(train_path, activity)
    for video_file in os.listdir(activity_path):
        video_path = os.path.join(activity_path, video_file)
        cap = cv2.VideoCapture(video_path)
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            resized_frame = cv2.resize(frame, (64, 64))
            train_frames.append(resized_frame)
            train_labels.append(i)
        cap.release()

# %%
# Convert training frames and labels to numpy arrays
X_train = np.array(train_frames)
y_train = np.array(train_labels)

# %%
# Load testing video frames and labels
test_frames = []
test_labels = []
for i, activity in enumerate(activities):
    activity_path = os.path.join(test_path, activity)
    for video_file in os.listdir(activity_path):
        video_path = os.path.join(activity_path, video_file)
        cap = cv2.VideoCapture(video_path)
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            resized_frame = cv2.resize(frame, (64, 64))
            test_frames.append(resized_frame)
            test_labels.append(i)
        cap.release()

# %%
# Convert testing frames and labels to numpy arrays
X_test = np.array(test_frames)
y_test = np.array(test_labels)

# Normalize pixel values
X_train = X_train / 255.0
X_test = X_test / 255.0
# Convert labels to one-hot vectors
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)

# %%
# Step 2: Define the model architecture
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
# Step 3: Compile and train the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=30, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 26/26 [==============================] - 14s 368ms/step - loss: 0.2550 - accuracy: 0.9091 - val_loss: 3.5440e-05 - val_accuracy: 1.0000
# Epoch 2/30
# 26/26 [==============================] - 8s 287ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 5.9099e-07 - val_accuracy: 1.0000
# Epoch 3/30
# 26/26 [==============================] - 7s 284ms/step - loss: 3.9721e-04 - accuracy: 1.0000 - val_loss: 2.3524e-07 - val_accuracy: 1.0000
# Epoch 4/30
# 26/26 [==============================] - 7s 280ms/step - loss: 1.0837e-04 - accuracy: 1.0000 - val_loss: 7.6872e-08 - val_accuracy: 1.0000
# Epoch 5/30
# 26/26 [==============================] - 7s 270ms/step - loss: 1.6341e-04 - accuracy: 1.0000 - val_loss: 1.7629e-08 - val_accuracy: 1.0000
# Epoch 6/30
# 26/26 [==============================] - 7s 283ms/step - loss: 4.0946e-05 - accuracy: 1.0000 - val_loss: 1.4450e-08 - val_accuracy: 1.0000
# Epoch 7/30
# 26/26 [==============================] - 7s 282ms/step - loss: 9.8903e-05 - accuracy: 1.0000 - val_loss: 3.7424e-08 - val_accuracy: 1.0000
# Epoch 8/30
# 26/26 [==============================] - 8s 299ms/step - loss: 1.6984e-05 - accuracy: 1.0000 - val_loss: 3.1211e-08 - val_accuracy: 1.0000
# Epoch 9/30
# 26/26 [==============================] - 7s 266ms/step - loss: 4.2532e-05 - accuracy: 1.0000 - val_loss: 2.0374e-08 - val_accuracy: 1.0000
# Epoch 10/30
# 26/26 [==============================] - 7s 275ms/step - loss: 3.5393e-05 - accuracy: 1.0000 - val_loss: 7.0803e-09 - val_accuracy: 1.0000
# Epoch 11/30
# 26/26 [==============================] - 7s 266ms/step - loss: 1.2157e-04 - accuracy: 1.0000 - val_loss: 2.4564e-09 - val_accuracy: 1.0000
# Epoch 12/30
# 26/26 [==============================] - 7s 257ms/step - loss: 4.7880e-05 - accuracy: 1.0000 - val_loss: 1.4450e-09 - val_accuracy: 1.0000
# Epoch 13/30
# 26/26 [==============================] - 7s 270ms/step - loss: 7.0808e-05 - accuracy: 1.0000 - val_loss: 2.1674e-09 - val_accuracy: 1.0000
# Epoch 14/30
# 26/26 [==============================] - 7s 259ms/step - loss: 5.6733e-06 - accuracy: 1.0000 - val_loss: 1.3005e-09 - val_accuracy: 1.0000
# Epoch 15/30
# 26/26 [==============================] - 7s 260ms/step - loss: 2.2057e-05 - accuracy: 1.0000 - val_loss: 2.8899e-10 - val_accuracy: 1.0000
# Epoch 16/30
# 26/26 [==============================] - 7s 269ms/step - loss: 4.8897e-06 - accuracy: 1.0000 - val_loss: 2.8899e-10 - val_accuracy: 1.0000
# Epoch 17/30
# 26/26 [==============================] - 7s 259ms/step - loss: 1.2062e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 18/30
# 26/26 [==============================] - 7s 281ms/step - loss: 4.6584e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 19/30
# 26/26 [==============================] - 7s 264ms/step - loss: 3.8722e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 20/30
# 26/26 [==============================] - 7s 260ms/step - loss: 5.2918e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 21/30
# 26/26 [==============================] - 7s 263ms/step - loss: 2.4183e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 22/30
# 26/26 [==============================] - 7s 259ms/step - loss: 1.0361e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 23/30
# 26/26 [==============================] - 7s 271ms/step - loss: 1.5227e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 24/30
# 26/26 [==============================] - 7s 267ms/step - loss: 1.0370e-04 - accuracy: 1.0000 - val_loss: 5.0863e-08 - val_accuracy: 1.0000
# Epoch 25/30
# 26/26 [==============================] - 7s 255ms/step - loss: 1.0226e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 26/30
# 26/26 [==============================] - 7s 261ms/step - loss: 4.3076e-04 - accuracy: 1.0000 - val_loss: 4.1116e-06 - val_accuracy: 1.0000
# Epoch 27/30
# 26/26 [==============================] - 7s 260ms/step - loss: 0.1905 - accuracy: 0.9600 - val_loss: 1.3031e-05 - val_accuracy: 1.0000
# Epoch 28/30
# 26/26 [==============================] - 7s 275ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 7.0832e-07 - val_accuracy: 1.0000
# Epoch 29/30
# 26/26 [==============================] - 7s 257ms/step - loss: 4.2944e-04 - accuracy: 1.0000 - val_loss: 2.4275e-07 - val_accuracy: 1.0000
# Epoch 30/30
# 26/26 [==============================] - 7s 256ms/step - loss: 4.4518e-04 - accuracy: 1.0000 - val_loss: 6.4012e-08 - val_accuracy: 1.0000

# %%
# Step 4: Save the trained model
model.save('model.h5')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from keras.models import load_model
# Load the trained model
model = load_model('model.h5')

# Make predictions on the training data
y_train_pred = model.predict(X_train)
y_train_pred = np.argmax(y_train_pred, axis=1)

# Convert the true labels to their corresponding class index
y_train_true = np.argmax(y_train, axis=1)

# Calculate accuracy
train_accuracy = accuracy_score(y_train_true, y_train_pred)

# Calculate precision, recall, and F1-score
train_precision = precision_score(y_train_true, y_train_pred, average='macro')
train_recall = recall_score(y_train_true, y_train_pred, average='macro')
train_f1 = f1_score(y_train_true, y_train_pred, average='macro')

# Print the evaluation metrics
print(f'Training Accuracy: {train_accuracy * 100:.2f}%')
print(f'Training Precision: {train_precision:.2f}')
print(f'Training Recall: {train_recall:.2f}')
print(f'Training F1-score: {train_f1:.2f}')
# Out:
# 26/26 [==============================] - 2s 59ms/step
# Training Accuracy: 100.00%
# Training Precision: 1.00
# Training Recall: 1.00
# Training F1-score: 1.00

# %%
from sklearn.metrics import classification_report

# Load the trained model
model = load_model('model.h5')

# Make predictions on the training data
y_train_pred = model.predict(X_train)
y_train_pred = np.argmax(y_train_pred, axis=1)

# Convert the true labels to their corresponding class index
y_train_true = np.argmax(y_train, axis=1)

# Generate classification report
train_report = classification_report(y_train_true, y_train_pred, target_names=activities)

# Print the classification report
print("Training Classification Report:")
print(train_report)
# Out:
# 26/26 [==============================] - 2s 65ms/step
# Training Classification Report:
#               precision    recall  f1-score   support
#
#      jogging       1.00      1.00      1.00       294
#   meditation       1.00      1.00      1.00       330
#       pushup       1.00      1.00      1.00       201
#
#     accuracy                           1.00       825
#    macro avg       1.00      1.00      1.00       825
# weighted avg       1.00      1.00      1.00       825

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Load the trained model
model = load_model('model.h5')

# Make predictions on the training data
y_train_pred = model.predict(X_train)
y_train_pred = np.argmax(y_train_pred, axis=1)

# Convert the true labels to their corresponding class index
y_train_true = np.argmax(y_train, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_train_true, y_train_pred)

# Define the class labels
class_labels = ['jogging', 'meditation', 'pushup']  # Replace with your class labels

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

# Set labels for x-axis and y-axis
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')

# Set x-tick and y-tick labels
plt.xticks(np.arange(len(class_labels)), class_labels, rotation=45)
plt.yticks(np.arange(len(class_labels)), class_labels, rotation=0)

# Set title for the plot
plt.title('Confusion Matrix')

# Show the plot
plt.show()
# Out:
# 26/26 [==============================] - 2s 74ms/step

# %%
###Testing

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the trained model
model = load_model('model.h5')

# Define the activities (classes)
activities = ['Jogging', 'Meditation','Pushup']  # Replace with your actual activity labels

# Load the test video
test_video_path = 'C:/Users/Vishwa/Desktop/HAR final/input videos/jogging.mp4'  # Replace with the path to your test video
cap = cv2.VideoCapture(test_video_path)

# Get the video properties
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
fps = cap.get(cv2.CAP_PROP_FPS)

# Create an output video writer
output_video_path = 'predicted_video.mp4'  # Replace with the desired output video path
fourcc = cv2.VideoWriter_fourcc(*'MJPG')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Read the video frames
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Preprocess the frame (resize and normalize)
    resized_frame = cv2.resize(frame, (64, 64))
    normalized_frame = resized_frame / 255.0

    # Add the batch dimension
    input_frame = np.expand_dims(normalized_frame, axis=0)

    # Make prediction on the input frame
    pred = model.predict(input_frame)
    pred_label = np.argmax(pred)
    activity = activities[pred_label]

    # Draw the predicted activity label on the frame
    cv2.putText(frame, activity, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0 , 255), 2)

    # Write the frame to the output video
    out.write(frame)

    # Display the frame with labeled activity
    cv2.imshow('Predicted Video', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and output video writer
cap.release()
out.release()

# Destroy all OpenCV windows
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 469ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
